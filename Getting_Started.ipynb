# %% [markdown]
# <a href="https://colab.research.google.com/github/jolyahSolutions/low-code-ml-sandbox/blob/main/Getting_Started.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = 'https://data.cdc.gov/api/views/jiwm-ppbh/rows.csv?accessType=DOWNLOAD'
heart_df = pd.read_csv(url, index_col=0)

# %%
heart_df.head()
# Out:
#      LocationAbbr    LocationDesc GeographicLevel DataSource  \
# Year
# 2019           AK  Aleutians East          County       NVSS
# 2019           AK  Aleutians West          County       NVSS
# 2019           AK       Anchorage          County       NVSS
# 2019           AK          Bethel          County       NVSS
# 2019           AK     Bristol Bay          County       NVSS
#
#                         Class                    Topic  Data_Value  \
# Year
# 2019  Cardiovascular Diseases  Heart Disease Mortality       182.4
# 2019  Cardiovascular Diseases  Heart Disease Mortality       172.6
# 2019  Cardiovascular Diseases  Heart Disease Mortality       255.6
# 2019  Cardiovascular Diseases  Heart Disease Mortality       343.4
# 2019  Cardiovascular Diseases  Heart Disease Mortality         NaN
#
#              Data_Value_Unit  \
# Year
# 2019  per 100,000 population
# 2019  per 100,000 population
# 2019  per 100,000 population
# 2019  per 100,000 population
# 2019  per 100,000 population
#
#                                         Data_Value_Type  \
# Year
# 2019  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 2019  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 2019  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 2019  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 2019  Age-adjusted, Spatially Smoothed, 3-year Avera...
#
#      Data_Value_Footnote_Symbol Data_Value_Footnote StratificationCategory1  \
# Year
# 2019                        NaN                 NaN                  Gender
# 2019                        NaN                 NaN                  Gender
# 2019                        NaN                 NaN                  Gender
# 2019                        NaN                 NaN                  Gender
# 2019                          ~   Insufficient Data                  Gender
#
#      Stratification1 StratificationCategory2 Stratification2 TopicID  \
# Year
# 2019         Overall          Race/Ethnicity         Overall      T2
# 2019         Overall          Race/Ethnicity         Overall      T2
# 2019         Overall          Race/Ethnicity         Overall      T2
# 2019         Overall          Race/Ethnicity         Overall      T2
# 2019         Overall          Race/Ethnicity         Overall      T2
#
#       LocationID      Y_lat       X_lon
# Year
# 2019        2013  55.442393 -161.959930
# 2019        2016  53.648343 -166.917533
# 2019        2020  61.159145 -149.104559
# 2019        2050  60.923648 -159.753262
# 2019        2060  58.753496 -156.694662

# %%
heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59094 entries, 2019 to 2019
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   LocationAbbr                59094 non-null  object
#  1   LocationDesc                59094 non-null  object
#  2   GeographicLevel             59094 non-null  object
#  3   DataSource                  59094 non-null  object
#  4   Class                       59094 non-null  object
#  5   Topic                       59094 non-null  object
#  6   Data_Value                  33087 non-null  float64
#  7   Data_Value_Unit             59094 non-null  object
#  8   Data_Value_Type             59094 non-null  object
#  9   Data_Value_Footnote_Symbol  26007 non-null  object
#  10  Data_Value_Footnote         26007 non-null  object
#  11  StratificationCategory1     59094 non-null  object
#  12  Stratification1             59094 non-null  object
#  13  StratificationCategory2     59094 non-null  object
#  14  Stratification2             59094 non-null  object
#  15  TopicID                     59094 non-null  object
#  16  LocationID                  59094 non-null  int64
#  17  Y_lat                       59076 non-null  float64
#  18  X_lon                       59076 non-null  float64
# dtypes: float64(3), int64(1), object(15)
# memory usage: 9.0+ MB

# %%
heart_df = pd.read_csv('/content/heart.csv', error_bad_lines=False, engine="python")
# Out:
# <ipython-input-7-452de3565408>:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   heart_df = pd.read_csv('/content/heart.csv', error_bad_lines=False, engine="python")

# %%
heart_df.head()
# Out:
#    Year LocationAbbr    LocationDesc GeographicLevel DataSource  \
# 0  2019           AK  Aleutians East          County       NVSS
# 1  2019           AK  Aleutians West          County       NVSS
# 2  2019           AK       Anchorage          County       NVSS
# 3  2019           AK          Bethel          County       NVSS
# 4  2019           AK     Bristol Bay          County       NVSS
#
#                      Class                    Topic  Data_Value  \
# 0  Cardiovascular Diseases  Heart Disease Mortality       182.4
# 1  Cardiovascular Diseases  Heart Disease Mortality       172.6
# 2  Cardiovascular Diseases  Heart Disease Mortality       255.6
# 3  Cardiovascular Diseases  Heart Disease Mortality       343.4
# 4  Cardiovascular Diseases  Heart Disease Mortality         NaN
#
#           Data_Value_Unit                                    Data_Value_Type  \
# 0  per 100,000 population  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 1  per 100,000 population  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 2  per 100,000 population  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 3  per 100,000 population  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 4  per 100,000 population  Age-adjusted, Spatially Smoothed, 3-year Avera...
#
#   Data_Value_Footnote_Symbol Data_Value_Footnote StratificationCategory1  \
# 0                        NaN                 NaN                  Gender
# 1                        NaN                 NaN                  Gender
# 2                        NaN                 NaN                  Gender
# 3                        NaN                 NaN                  Gender
# 4                          ~   Insufficient Data                  Gender
#
#   Stratification1 StratificationCategory2 Stratification2 TopicID  LocationID  \
# 0         Overall          Race/Ethnicity         Overall      T2        2013
# 1         Overall          Race/Ethnicity         Overall      T2        2016
# 2         Overall          Race/Ethnicity         Overall      T2        2020
# 3         Overall          Race/Ethnicity         Overall      T2        2050
# 4         Overall          Race/Ethnicity         Overall      T2        2060
#
#        Y_lat       X_lon
# 0  55.442393 -161.959930
# 1  53.648343 -166.917533
# 2  61.159145 -149.104559
# 3  60.923648 -159.753262
# 4  58.753496 -156.694662

# %%
heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59094 entries, 0 to 59093
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Year                        59094 non-null  int64
#  1   LocationAbbr                59094 non-null  object
#  2   LocationDesc                59094 non-null  object
#  3   GeographicLevel             59094 non-null  object
#  4   DataSource                  59094 non-null  object
#  5   Class                       59094 non-null  object
#  6   Topic                       59094 non-null  object
#  7   Data_Value                  33087 non-null  float64
#  8   Data_Value_Unit             59094 non-null  object
#  9   Data_Value_Type             59094 non-null  object
#  10  Data_Value_Footnote_Symbol  26007 non-null  object
#  11  Data_Value_Footnote         26007 non-null  object
#  12  StratificationCategory1     59094 non-null  object
#  13  Stratification1             59094 non-null  object
#  14  StratificationCategory2     59094 non-null  object
#  15  Stratification2             59094 non-null  object
#  16  TopicID                     59094 non-null  object
#  17  LocationID                  59094 non-null  int64
#  18  Y_lat                       59076 non-null  float64
#  19  X_lon                       59076 non-null  float64
# dtypes: float64(3), int64(2), object(15)
# memory usage: 9.0+ MB

# %%
heart_df.isnull().sum()
# Out:
# Year                              0
# LocationAbbr                      0
# LocationDesc                      0
# GeographicLevel                   0
# DataSource                        0
# Class                             0
# Topic                             0
# Data_Value                    26007
# Data_Value_Unit                   0
# Data_Value_Type                   0
# Data_Value_Footnote_Symbol    33087
# Data_Value_Footnote           33087
# StratificationCategory1           0
# Stratification1                   0
# StratificationCategory2           0
# Stratification2                   0
# TopicID                           0
# LocationID                        0
# Y_lat                            18
# X_lon                            18
# dtype: int64

# %%
heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59094 entries, 2019 to 2019
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   LocationAbbr                59094 non-null  object
#  1   LocationDesc                59094 non-null  object
#  2   GeographicLevel             59094 non-null  object
#  3   DataSource                  59094 non-null  object
#  4   Class                       59094 non-null  object
#  5   Topic                       59094 non-null  object
#  6   Data_Value                  33087 non-null  float64
#  7   Data_Value_Unit             59094 non-null  object
#  8   Data_Value_Type             59094 non-null  object
#  9   Data_Value_Footnote_Symbol  26007 non-null  object
#  10  Data_Value_Footnote         26007 non-null  object
#  11  StratificationCategory1     59094 non-null  object
#  12  Stratification1             59094 non-null  object
#  13  StratificationCategory2     59094 non-null  object
#  14  Stratification2             59094 non-null  object
#  15  TopicID                     59094 non-null  object
#  16  LocationID                  59094 non-null  int64
#  17  Y_lat                       59076 non-null  float64
#  18  X_lon                       59076 non-null  float64
# dtypes: float64(3), int64(1), object(15)
# memory usage: 9.0+ MB

# %%
heart_df.isnull().sum()
# Out:
# LocationAbbr                      0
# LocationDesc                      0
# GeographicLevel                   0
# DataSource                        0
# Class                             0
# Topic                             0
# Data_Value                    26007
# Data_Value_Unit                   0
# Data_Value_Type                   0
# Data_Value_Footnote_Symbol    33087
# Data_Value_Footnote           33087
# StratificationCategory1           0
# Stratification1                   0
# StratificationCategory2           0
# Stratification2                   0
# TopicID                           0
# LocationID                        0
# Y_lat                            18
# X_lon                            18
# dtype: int64

# %%
heart_df.isna()
# Out:
#       LocationAbbr  LocationDesc  GeographicLevel  DataSource  Class  Topic  \
# Year
# 2019         False         False            False       False  False  False
# 2019         False         False            False       False  False  False
# 2019         False         False            False       False  False  False
# 2019         False         False            False       False  False  False
# 2019         False         False            False       False  False  False
# ...            ...           ...              ...         ...    ...    ...
# 2019         False         False            False       False  False  False
# 2019         False         False            False       False  False  False
# 2019         False         False            False       False  False  False
# 2019         False         False            False       False  False  False
# 2019         False         False            False       False  False  False
#
#       Data_Value  Data_Value_Unit  Data_Value_Type  \
# Year
# 2019       False            False            False
# 2019       False            False            False
# 2019       False            False            False
# 2019       False            False            False
# 2019        True            False            False
# ...          ...              ...              ...
# 2019        True            False            False
# 2019        True            False            False
# 2019       False            False            False
# 2019       False            False            False
# 2019        True            False            False
#
#       Data_Value_Footnote_Symbol  Data_Value_Footnote  \
# Year
# 2019                        True                 True
# 2019                        True                 True
# 2019                        True                 True
# 2019                        True                 True
# 2019                       False                False
# ...                          ...                  ...
# 2019                       False                False
# 2019                       False                False
# 2019                        True                 True
# 2019                        True                 True
# 2019                       False                False
#
#       StratificationCategory1  Stratification1  StratificationCategory2  \
# Year
# 2019                    False            False                    False
# 2019                    False            False                    False
# 2019                    False            False                    False
# 2019                    False            False                    False
# 2019                    False            False                    False
# ...                       ...              ...                      ...
# 2019                    False            False                    False
# 2019                    False            False                    False
# 2019                    False            False                    False
# 2019                    False            False                    False
# 2019                    False            False                    False
#
#       Stratification2  TopicID  LocationID  Y_lat  X_lon
# Year
# 2019            False    False       False  False  False
# 2019            False    False       False  False  False
# 2019            False    False       False  False  False
# 2019            False    False       False  False  False
# 2019            False    False       False  False  False
# ...               ...      ...         ...    ...    ...
# 2019            False    False       False  False  False
# 2019            False    False       False  False  False
# 2019            False    False       False  False  False
# 2019            False    False       False  False  False
# 2019            False    False       False  False  False
#
# [59094 rows x 19 columns]

# %%
heart_df[heart_df['Data_Value'] > 400]
# Out:
#      LocationAbbr       LocationDesc GeographicLevel DataSource  \
# Year
# 2019           AK               Nome          County       NVSS
# 2019           AK   Northwest Arctic          County       NVSS
# 2019           AK             Bethel          County       NVSS
# 2019           AK         Dillingham          County       NVSS
# 2019           AK               Nome          County       NVSS
# ...           ...                ...             ...        ...
# 2019           WY        Park County          County       NVSS
# 2019           WY    Sheridan County          County       NVSS
# 2019           WY  Sweetwater County          County       NVSS
# 2019           WY      Weston County          County       NVSS
# 2019           WY            Wyoming           State       NVSS
#
#                         Class                    Topic  Data_Value  \
# Year
# 2019  Cardiovascular Diseases  Heart Disease Mortality       442.1
# 2019  Cardiovascular Diseases  Heart Disease Mortality       404.7
# 2019  Cardiovascular Diseases  Heart Disease Mortality       485.7
# 2019  Cardiovascular Diseases  Heart Disease Mortality       518.5
# 2019  Cardiovascular Diseases  Heart Disease Mortality       551.4
# ...                       ...                      ...         ...
# 2019  Cardiovascular Diseases  Heart Disease Mortality       548.9
# 2019  Cardiovascular Diseases  Heart Disease Mortality       666.0
# 2019  Cardiovascular Diseases  Heart Disease Mortality       497.9
# 2019  Cardiovascular Diseases  Heart Disease Mortality       656.2
# 2019  Cardiovascular Diseases  Heart Disease Mortality       432.2
#
#              Data_Value_Unit  \
# Year
# 2019  per 100,000 population
# 2019  per 100,000 population
# 2019  per 100,000 population
# 2019  per 100,000 population
# 2019  per 100,000 population
# ...                      ...
# 2019  per 100,000 population
# 2019  per 100,000 population
# 2019  per 100,000 population
# 2019  per 100,000 population
# 2019  per 100,000 population
#
#                                         Data_Value_Type  \
# Year
# 2019  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 2019  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 2019  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 2019  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 2019  Age-adjusted, Spatially Smoothed, 3-year Avera...
# ...                                                 ...
# 2019  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 2019  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 2019  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 2019  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 2019                  Age-adjusted, 3-year Average Rate
#
#      Data_Value_Footnote_Symbol Data_Value_Footnote StratificationCategory1  \
# Year
# 2019                        NaN                 NaN                  Gender
# 2019                        NaN                 NaN                  Gender
# 2019                        NaN                 NaN                  Gender
# 2019                        NaN                 NaN                  Gender
# 2019                        NaN                 NaN                  Gender
# ...                         ...                 ...                     ...
# 2019                        NaN                 NaN                  Gender
# 2019                        NaN                 NaN                  Gender
# 2019                        NaN                 NaN                  Gender
# 2019                        NaN                 NaN                  Gender
# 2019                        NaN                 NaN                  Gender
#
#      Stratification1 StratificationCategory2  \
# Year
# 2019         Overall          Race/Ethnicity
# 2019         Overall          Race/Ethnicity
# 2019            Male          Race/Ethnicity
# 2019            Male          Race/Ethnicity
# 2019            Male          Race/Ethnicity
# ...              ...                     ...
# 2019            Male          Race/Ethnicity
# 2019            Male          Race/Ethnicity
# 2019            Male          Race/Ethnicity
# 2019            Male          Race/Ethnicity
# 2019            Male          Race/Ethnicity
#
#                          Stratification2 TopicID  LocationID      Y_lat  \
# Year
# 2019                             Overall      T2        2180  64.903977
# 2019                             Overall      T2        2188  67.065077
# 2019                             Overall      T2        2050  60.923648
# 2019                             Overall      T2        2070  59.803704
# 2019                             Overall      T2        2180  64.903977
# ...                                  ...     ...         ...        ...
# 2019  American Indian and Alaskan Native      T2       56029  44.520316
# 2019  American Indian and Alaskan Native      T2       56033  44.788939
# 2019  American Indian and Alaskan Native      T2       56037  41.657740
# 2019  American Indian and Alaskan Native      T2       56045  43.841816
# 2019  American Indian and Alaskan Native      T2          56  42.998400
#
#            X_lon
# Year
# 2019 -163.946230
# 2019 -159.726882
# 2019 -159.753262
# 2019 -158.181350
# 2019 -163.946230
# ...          ...
# 2019 -109.592102
# 2019 -106.876358
# 2019 -108.886499
# 2019 -104.571415
# 2019 -107.552000
#
# [10360 rows x 19 columns]

# %%
heart_df.Stratification2.unique()
# Out:
# array(['Overall', 'White', 'Black', 'Hispanic',
#        'Asian and Pacific Islander', 'American Indian and Alaskan Native'],
#       dtype=object)

# %%
import seaborn as sns
sns.violinplot(x="Data_Value", y="Stratification2", data=heart_df)

# %%
import seaborn as sns
sns.displot(heart_df['Data_Value'])
